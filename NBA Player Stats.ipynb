# %%
import pandas as pd

# Retrieve HTML table data
url = 'https://www.basketball-reference.com/leagues/NBA_2023_per_game.html'
html = pd.read_html(url, header = 0)
df2023 = html[0]

# %%
raw = df2023.drop(df2023[df2023.Age == 'Age'].index)
raw
# Out:
#       Rk            Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1  Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3  ...  .702
# 1      2      Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  ...  .364
# 2      3       Bam Adebayo   C  25  MIA  75  75  34.6  8.0  14.9  ...  .806
# 3      4      Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5  ...  .812
# 4      5      Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  ...  .750
# ..   ...               ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 700  535    Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  ...  .692
# 701  536        Trae Young  PG  24  ATL  73  73  34.8  8.2  19.0  ...  .886
# 702  537    Omer Yurtseven   C  24  MIA   9   0   9.2  1.8   3.0  ...  .833
# 703  538       Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9  ...  .686
# 704  539       Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8  ...  .697
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    1.8  4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2
# 1    5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 3    0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9
# 4    1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0
# ..   ...  ...   ...   ...  ...  ...  ...  ...   ...
# 700  1.3  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4
# 701  0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2
# 702  0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4
# 703  1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5
# 704  3.1  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8
#
# [679 rows x 30 columns]

# %% [markdown]
# **Column Descriptions**
# Column | Description
# ---|---
# Rk | Rank
# Pos | Position
# Age | Player's age on February 1 of the season
# Tm | Team
# G | Games
# GS | Games Started
# MP | Minutes Played Per Game
# FG | Field Goals Per Game
# FGA | Field Goal Attempts Per Game
# FG% | Field Goal Percentage
# 3P | 3-Point Field Goals Per Game
# 3PA | 3-Point Field Goal Attempts Per Game
# 3P% | FG% on 3-Pt FGAs.
# 2P | 2-Point Field Goals Per Game
# 2PA | 2-Point Field Goal Attempts Per Game
# 2P% | FG% on 2-Pt FGAs.
# eFG% | Effective Field Goal Percentage
# FT | Free Throws Per Game
# FTA | Free Throw Attempts Per Game
# FT% | Free Throw Percentage
# ORB | Offensive Rebounds Per Game
# DRB | Defensive Rebounds Per Game
# TRB | Total Rebounds Per Game
# AST | Assists Per Game
# STL | Steals Per Game
# BLK | Blocks Per Game
# TOV | Turnovers Per Game
# PF | Personal Fouls Per Game
# PTS | Points Per Game

# %% [markdown]
# **Data Cleaning**

# %%
# Data Dimension
raw.shape
# Out:
# (679, 30)

# %%
# Dataframe contents
raw.head()
# Out:
#   Rk            Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1  Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3  ...  .702  1.8
# 1  2      Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  ...  .364  5.1
# 2  3       Bam Adebayo   C  25  MIA  75  75  34.6  8.0  14.9  ...  .806  2.5
# 3  4      Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5  ...  .812  0.7
# 4  5      Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  ...  .750  1.1
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.1   6.0  0.9  0.6  0.5  1.1  1.9   9.2
# 1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 3  1.3   2.1  1.1  0.3  0.3  0.7  1.7   7.9
# 4  3.7   4.8  1.3  0.6  0.6  0.8  1.9   9.0
#
# [5 rows x 30 columns]

# %%
# Check for missing values
raw.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        3
# 3P         0
# 3PA        0
# 3P%       24
# 2P         0
# 2PA        0
# 2P%        7
# eFG%       3
# FT         0
# FTA        0
# FT%       37
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
# Replace missing values with 0
df = raw.fillna(0)
df.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
# Drop "Rank" column
df = df.drop(["Rk"], axis = 1)
df
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  \
# 0    Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3  .485  ...  .702
# 1        Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  .597  ...  .364
# 2         Bam Adebayo   C  25  MIA  75  75  34.6  8.0  14.9  .540  ...  .806
# 3        Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5  .427  ...  .812
# 4        Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  .470  ...  .750
# ..                ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 700    Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  .545  ...  .692
# 701        Trae Young  PG  24  ATL  73  73  34.8  8.2  19.0  .429  ...  .886
# 702    Omer Yurtseven   C  24  MIA   9   0   9.2  1.8   3.0  .593  ...  .833
# 703       Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9  .627  ...  .686
# 704       Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8  .634  ...  .697
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    1.8  4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2
# 1    5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 3    0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9
# 4    1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0
# ..   ...  ...   ...   ...  ...  ...  ...  ...   ...
# 700  1.3  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4
# 701  0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2
# 702  0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4
# 703  1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5
# 704  3.1  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8
#
# [679 rows x 29 columns]

# %%
# Write to csv file
df.to_csv("nba2023.csv", index=False)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Read data
df = pd.read_csv("nba2023.csv")
df
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0    Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  0.485  ...
# 1        Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  0.597  ...
# 2         Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  0.540  ...
# 3        Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  0.427  ...
# 4        Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  0.470  ...
# ..                ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 674    Thaddeus Young  PF   34  TOR  54   9  14.7  2.0   3.7  0.545  ...
# 675        Trae Young  PG   24  ATL  73  73  34.8  8.2  19.0  0.429  ...
# 676    Omer Yurtseven   C   24  MIA   9   0   9.2  1.8   3.0  0.593  ...
# 677       Cody Zeller   C   30  MIA  15   2  14.5  2.5   3.9  0.627  ...
# 678       Ivica Zubac   C   25  LAC  76  76  28.6  4.3   6.8  0.634  ...
#
#        FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    0.702  1.8  4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2
# 1    0.364  5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    0.806  2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 3    0.812  0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9
# 4    0.750  1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0
# ..     ...  ...  ...   ...   ...  ...  ...  ...  ...   ...
# 674  0.692  1.3  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4
# 675  0.886  0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2
# 676  0.833  0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4
# 677  0.686  1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5
# 678  0.697  3.1  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8
#
# [679 rows x 29 columns]

# %%
# Overview of data types of each column in the dataframe
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %% [markdown]
# Which player scored the most points Per Game (PTS)?

# %%
player_max_pts = df[df.PTS == df.PTS.max()]
player_max_pts
# Out:
#           Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 184  Joel Embiid   C   28  PHI  66  66  34.6  11.0  20.1  0.548  ...  0.857
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 184  1.7  8.4  10.2  4.2  1.0  1.7  3.4  3.1  33.1
#
# [1 rows x 29 columns]

# %%
# What team is the player from? 
player_max_pts.Tm

# Which position is the player playing at?
player_max_pts.Pos

# How many games did the player played in the season?
player_max_pts.G
# Out:
# 184    66
# Name: G, dtype: int64

# %%
# Which players scored more than 20 Points Per Game (PTS)?
df[df.PTS > 20]
# Out:
#                       Player    Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 2                Bam Adebayo      C   25  MIA  75  75  34.6   8.0  14.9
# 12     Giannis Antetokounmpo     PF   28  MIL  63  63  32.1  11.2  20.3
# 24               LaMelo Ball     PG   21  CHO  36  36  35.2   8.2  20.0
# 29              Desmond Bane     SG   24  MEM  58  58  31.7   7.8  16.2
# 44              Bradley Beal     SG   29  WAS  50  50  33.5   8.9  17.6
# 63          Bojan Bogdanović     PF   33  DET  59  59  32.1   7.3  14.9
# 66              Devin Booker     SG   26  PHO  53  53  34.6   9.9  20.1
# 77             Mikal Bridges  SF-SG   26  TOT  83  83  35.7   7.1  15.3
# 79             Mikal Bridges     SG   26  BRK  27  27  34.2   8.9  18.6
# 85              Jaylen Brown     SF   26  BOS  67  67  35.9  10.1  20.6
# 92             Jalen Brunson     PG   26  NYK  68  68  35.0   8.6  17.6
# 100             Jimmy Butler     PF   33  MIA  64  64  33.4   7.5  13.9
# 122          Jordan Clarkson     SG   30  UTA  61  61  32.6   7.5  16.9
# 139            Stephen Curry     PG   34  GSW  56  56  34.7  10.0  20.2
# 141            Anthony Davis      C   29  LAL  56  54  34.0   9.7  17.2
# 150            DeMar DeRozan     SF   33  CHI  74  74  36.2   8.9  17.6
# 160              Luka Dončić     PG   23  DAL  66  66  36.2  10.9  22.0
# 174             Kevin Durant     PF   34  TOT  47  47  35.6  10.3  18.3
# 175             Kevin Durant     PF   34  BRK  39  39  36.0  10.5  18.8
# 176             Kevin Durant     PF   34  PHO   8   8  33.6   9.1  16.0
# 179          Anthony Edwards     SG   21  MIN  79  79  36.0   8.9  19.5
# 184              Joel Embiid      C   28  PHI  66  66  34.6  11.0  20.1
# 198             De'Aaron Fox     PG   25  SAC  73  73  33.4   9.3  18.2
# 202           Darius Garland     PG   23  CLE  69  69  35.5   7.6  16.4
# 206              Paul George     SF   32  LAC  56  56  34.6   8.2  17.9
# 209  Shai Gilgeous-Alexander     PG   24  OKC  68  68  35.5  10.4  20.3
# 221             Jerami Grant     PF   28  POR  63  63  35.7   6.9  14.5
# 228              Jalen Green     SG   20  HOU  76  76  34.2   7.4  17.9
# 239        Tyrese Haliburton     PG   22  IND  56  56  33.6   7.4  15.0
# 245             James Harden     PG   33  PHI  58  58  36.8   6.4  14.5
# 265              Tyler Herro     SG   23  MIA  67  67  34.9   7.3  16.6
# 292           Brandon Ingram     SF   25  NOP  45  45  34.2   9.0  18.6
# 293             Kyrie Irving  PG-SG   30  TOT  60  60  37.4   9.9  20.1
# 294             Kyrie Irving     PG   30  BRK  40  40  37.0  10.0  20.5
# 295             Kyrie Irving     SG   30  DAL  20  20  38.2   9.8  19.2
# 306             LeBron James     PF   38  LAL  55  54  35.5  11.1  22.2
# 315           Keldon Johnson     SF   23  SAS  63  63  32.7   8.0  17.7
# 318             Nikola Jokić      C   27  DEN  69  69  33.7   9.4  14.8
# 355               Kyle Kuzma     PF   27  WAS  64  64  35.0   8.0  17.8
# 360              Zach LaVine     SG   27  CHI  77  77  35.9   8.7  18.0
# 369            Kawhi Leonard     SF   31  LAC  52  50  33.6   8.6  16.8
# 373           Damian Lillard     PG   32  POR  58  58  36.3   9.6  20.7
# 392          Lauri Markkanen     PF   25  UTA  66  66  34.4   8.7  17.3
# 403             Tyrese Maxey     SG   22  PHI  60  41  33.6   7.3  15.2
# 407              CJ McCollum     PG   31  NOP  75  75  35.3   7.8  17.9
# 427         Donovan Mitchell     SG   26  CLE  68  68  35.8  10.0  20.6
# 435                Ja Morant     PG   23  MEM  61  59  31.9   9.3  19.9
# 442          Dejounte Murray     SG   26  ATL  74  74  36.4   8.3  17.8
# 482          Kelly Oubre Jr.     SF   27  CHO  48  40  32.3   7.4  17.1
# 497             Jordan Poole     PG   23  GSW  82  43  30.0   6.7  15.6
# 502       Kristaps Porziņģis      C   27  WAS  65  65  32.6   7.8  15.7
# 514            Julius Randle     PF   28  NYK  77  77  35.5   8.5  18.6
# 541             Terry Rozier     SG   28  CHO  63  63  35.3   7.8  18.9
# 565            Pascal Siakam     PF   28  TOR  71  71  37.4   8.9  18.5
# 570          Anfernee Simons     SG   23  POR  62  62  35.0   7.5  16.9
# 590             Jayson Tatum     SF   24  BOS  74  74  36.9   9.8  21.1
# 598            Klay Thompson     SF   32  GSW  69  69  33.0   7.9  18.1
# 609       Karl-Anthony Towns     PF   27  MIN  29  29  33.0   7.3  14.8
# 664          Zion Williamson     PF   22  NOP  29  29  33.0   9.8  16.2
# 675               Trae Young     PG   24  ATL  73  73  34.8   8.2  19.0
#
#        FG%  ...    FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 2    0.540  ...  0.806  2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 12   0.553  ...  0.645  2.2  9.6  11.8   5.7  0.8  0.8  3.9  3.1  31.1
# 24   0.411  ...  0.836  1.2  5.3   6.4   8.4  1.3  0.3  3.6  3.3  23.3
# 29   0.479  ...  0.883  0.7  4.3   5.0   4.4  1.0  0.4  2.2  2.6  21.5
# 44   0.506  ...  0.842  0.8  3.1   3.9   5.4  0.9  0.7  2.9  2.1  23.2
# 63   0.488  ...  0.884  0.6  3.2   3.8   2.6  0.6  0.1  2.3  1.9  21.6
# 66   0.494  ...  0.855  0.9  3.7   4.5   5.5  1.0  0.3  2.7  3.0  27.8
# 77   0.468  ...  0.895  1.0  3.4   4.4   3.3  1.1  0.7  1.5  1.9  20.1
# 79   0.475  ...  0.894  0.9  3.6   4.5   2.7  1.0  0.6  1.8  1.6  26.1
# 85   0.491  ...  0.765  1.2  5.7   6.9   3.5  1.1  0.4  2.9  2.6  26.6
# 92   0.491  ...  0.829  0.6  3.0   3.5   6.2  0.9  0.2  2.1  2.2  24.0
# 100  0.539  ...  0.850  2.2  3.7   5.9   5.3  1.8  0.3  1.6  1.3  22.9
# 122  0.444  ...  0.816  1.2  2.9   4.0   4.4  0.5  0.2  3.0  2.0  20.8
# 139  0.493  ...  0.915  0.7  5.4   6.1   6.3  0.9  0.4  3.2  2.1  29.4
# 141  0.563  ...  0.784  3.5  9.1  12.5   2.6  1.1  2.0  2.2  2.6  25.9
# 150  0.504  ...  0.872  0.5  4.2   4.6   5.1  1.1  0.5  2.1  2.5  24.5
# 160  0.496  ...  0.742  0.8  7.8   8.6   8.0  1.4  0.5  3.6  2.5  32.4
# 174  0.560  ...  0.919  0.4  6.3   6.7   5.0  0.7  1.4  3.3  2.1  29.1
# 175  0.559  ...  0.934  0.4  6.4   6.7   5.3  0.8  1.5  3.5  2.4  29.7
# 176  0.570  ...  0.833  0.4  6.0   6.4   3.5  0.3  1.3  2.5  0.9  26.0
# 179  0.459  ...  0.756  0.6  5.2   5.8   4.4  1.6  0.7  3.3  2.4  24.6
# 184  0.548  ...  0.857  1.7  8.4  10.2   4.2  1.0  1.7  3.4  3.1  33.1
# 198  0.512  ...  0.780  0.5  3.6   4.2   6.1  1.1  0.3  2.5  2.4  25.0
# 202  0.462  ...  0.863  0.4  2.3   2.7   7.8  1.2  0.1  2.9  2.1  21.6
# 206  0.457  ...  0.871  0.8  5.3   6.1   5.1  1.5  0.4  3.1  2.8  23.8
# 209  0.510  ...  0.905  0.9  4.0   4.8   5.5  1.6  1.0  2.8  2.8  31.4
# 221  0.475  ...  0.813  0.8  3.7   4.5   2.4  0.8  0.8  1.8  2.4  20.5
# 228  0.416  ...  0.786  0.6  3.2   3.7   3.7  0.8  0.2  2.6  1.7  22.1
# 239  0.490  ...  0.871  0.6  3.1   3.7  10.4  1.6  0.4  2.5  1.2  20.7
# 245  0.441  ...  0.867  0.7  5.4   6.1  10.7  1.2  0.5  3.4  1.9  21.0
# 265  0.439  ...  0.934  0.4  5.0   5.4   4.2  0.8  0.2  2.4  1.5  20.1
# 292  0.484  ...  0.882  0.5  5.0   5.5   5.8  0.7  0.4  3.3  2.6  24.7
# 293  0.494  ...  0.905  1.0  4.1   5.1   5.5  1.1  0.8  2.1  2.8  27.1
# 294  0.486  ...  0.883  1.0  4.2   5.1   5.3  1.0  0.8  2.3  2.7  27.1
# 295  0.510  ...  0.947  1.1  4.0   5.0   6.0  1.3  0.6  1.9  2.8  27.0
# 306  0.500  ...  0.768  1.2  7.1   8.3   6.8  0.9  0.6  3.2  1.6  28.9
# 315  0.452  ...  0.749  0.9  4.2   5.0   2.9  0.7  0.2  2.1  2.0  22.0
# 318  0.632  ...  0.822  2.4  9.4  11.8   9.8  1.3  0.7  3.6  2.5  24.5
# 355  0.448  ...  0.730  0.9  6.4   7.2   3.7  0.6  0.5  3.0  2.3  21.2
# 360  0.485  ...  0.848  0.5  3.9   4.5   4.2  0.9  0.2  2.5  2.1  24.8
# 369  0.512  ...  0.871  1.1  5.4   6.5   3.9  1.4  0.5  1.7  1.6  23.8
# 373  0.463  ...  0.914  0.8  4.0   4.8   7.3  0.9  0.3  3.3  1.9  32.2
# 392  0.499  ...  0.875  2.0  6.7   8.6   1.9  0.6  0.6  1.9  2.1  25.6
# 403  0.481  ...  0.845  0.4  2.6   2.9   3.5  0.8  0.1  1.3  2.2  20.3
# 407  0.437  ...  0.769  0.7  3.6   4.4   5.7  0.9  0.5  2.4  2.0  20.9
# 427  0.484  ...  0.867  0.9  3.3   4.3   4.4  1.5  0.4  2.6  2.5  28.3
# 435  0.466  ...  0.748  1.0  4.9   5.9   8.1  1.1  0.3  3.4  1.6  26.2
# 442  0.464  ...  0.832  0.7  4.5   5.3   6.1  1.5  0.3  2.2  1.4  20.5
# 482  0.431  ...  0.760  1.4  3.8   5.2   1.1  1.4  0.4  1.3  2.9  20.3
# 497  0.430  ...  0.870  0.4  2.4   2.7   4.5  0.8  0.3  3.1  2.6  20.4
# 502  0.498  ...  0.851  1.8  6.6   8.4   2.7  0.9  1.5  2.1  3.0  23.2
# 514  0.459  ...  0.757  1.8  8.1  10.0   4.1  0.6  0.3  2.8  3.0  25.1
# 541  0.415  ...  0.809  0.8  3.3   4.1   5.1  1.2  0.3  2.1  1.9  21.1
# 565  0.480  ...  0.774  1.8  6.0   7.8   5.8  0.9  0.5  2.4  3.2  24.2
# 570  0.447  ...  0.894  0.3  2.3   2.6   4.1  0.7  0.2  2.1  2.3  21.1
# 590  0.466  ...  0.854  1.1  7.7   8.8   4.6  1.1  0.7  2.9  2.2  30.1
# 598  0.436  ...  0.879  0.6  3.6   4.1   2.4  0.7  0.4  1.8  1.9  21.9
# 609  0.495  ...  0.874  1.7  6.5   8.1   4.8  0.7  0.6  3.0  3.8  20.8
# 664  0.608  ...  0.714  2.0  5.0   7.0   4.6  1.1  0.6  3.4  2.2  26.0
# 675  0.429  ...  0.886  0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2
#
# [60 rows x 29 columns]

# %%
# Which player had the highest 3-Point Field Goals Per Game (3P)?
df[df["3P"] == df["3P"].max()]

# Which player had the highest Assists Per Game (AST)?
df[df["AST"] == df["AST"].max()]
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 245  James Harden  PG   33  PHI  58  58  36.8  6.4  14.5  0.441  ...  0.867
#
#      ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 245  0.7  5.4  6.1  10.7  1.2  0.5  3.4  1.9  21.0
#
# [1 rows x 29 columns]

# %% [markdown]
# **GroupBy() function**

# %%
# Which player scored the highest (PTS) in the Los Angeles Lakers?
la_lakers = df.groupby("Tm").get_group("LAL")
la_lakers[la_lakers.PTS == la_lakers.PTS.max()]
# Out:
#            Player Pos  Age   Tm   G  GS    MP    FG   FGA  FG%  ...    FT%  \
# 306  LeBron James  PF   38  LAL  55  54  35.5  11.1  22.2  0.5  ...  0.768
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 306  1.2  7.1  8.3  6.8  0.9  0.6  3.2  1.6  28.9
#
# [1 rows x 29 columns]

# %% [markdown]
# Of the 5 positions, which position scores the most points?

# %%
# Group players by their positions
df.groupby("Pos").PTS.describe()
# Out:
#        count       mean        std  min     25%    50%     75%   max
# Pos
# C      139.0   7.614388   5.542413  0.0   3.750   6.10  10.250  33.1
# PF     121.0   9.400826   7.131602  0.0   4.500   7.60  11.200  31.1
# PF-C     1.0   6.400000        NaN  6.4   6.400   6.40   6.400   6.4
# PF-SF    1.0   7.500000        NaN  7.5   7.500   7.50   7.500   7.5
# PG     116.0  10.349138   7.785276  0.0   4.525   7.95  14.450  32.4
# PG-SG    2.0  16.050000  15.627060  5.0  10.525  16.05  21.575  27.1
# SF     133.0   8.336090   6.227460  0.0   3.900   6.70  11.100  30.1
# SF-PF    1.0   6.600000        NaN  6.6   6.600   6.60   6.600   6.6
# SF-SG    2.0  12.100000  11.313708  4.1   8.100  12.10  16.100  20.1
# SG     161.0   8.757143   6.247607  0.0   4.500   7.30  11.100  28.3
# SG-PG    2.0  11.750000   7.848885  6.2   8.975  11.75  14.525  17.3

# %% [markdown]
# Of the 5 positions, which position scores the most points?

# %%
# Group players by their positions
df.groupby('Pos').PTS.describe()

# Show only the 5 traditional positions (those having combo positions will be removed from the analysis)
positions = ['C','PF','SF','PG','SG']
pos = df[df["Pos"].isin(positions)]
pos
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0    Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  0.485  ...
# 1        Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  0.597  ...
# 2         Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  0.540  ...
# 3        Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  0.427  ...
# 4        Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  0.470  ...
# ..                ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 674    Thaddeus Young  PF   34  TOR  54   9  14.7  2.0   3.7  0.545  ...
# 675        Trae Young  PG   24  ATL  73  73  34.8  8.2  19.0  0.429  ...
# 676    Omer Yurtseven   C   24  MIA   9   0   9.2  1.8   3.0  0.593  ...
# 677       Cody Zeller   C   30  MIA  15   2  14.5  2.5   3.9  0.627  ...
# 678       Ivica Zubac   C   25  LAC  76  76  28.6  4.3   6.8  0.634  ...
#
#        FT%  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    0.702  1.8  4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2
# 1    0.364  5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    0.806  2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 3    0.812  0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9
# 4    0.750  1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0
# ..     ...  ...  ...   ...   ...  ...  ...  ...  ...   ...
# 674  0.692  1.3  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4
# 675  0.886  0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2
# 676  0.833  0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4
# 677  0.686  1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5
# 678  0.697  3.1  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8
#
# [670 rows x 29 columns]

# %%
# Take a look at the descriptive statistics
pos.groupby("Pos").describe()
# Out:
#        Age                                                         G  \
#      count       mean       std   min   25%   50%   75%   max  count
# Pos
# C    139.0  26.215827  4.242235  19.0  23.0  25.0  29.0  42.0  139.0
# PF   121.0  26.512397  4.837554  19.0  23.0  26.0  30.0  39.0  121.0
# PG   116.0  26.879310  4.736822  19.0  23.0  26.0  31.0  37.0  116.0
# SF   133.0  25.375940  3.508866  19.0  23.0  25.0  27.0  36.0  133.0
# SG   161.0  25.254658  4.114425  19.0  22.0  25.0  28.0  36.0  161.0
#
#                 ...     PF         PTS                                         \
#           mean  ...    75%  max  count       mean       std  min    25%   50%
# Pos             ...
# C    43.503597  ...  2.400  3.6  139.0   7.614388  5.542413  0.0  3.750  6.10
# PF   45.074380  ...  2.200  5.0  121.0   9.400826  7.131602  0.0  4.500  7.60
# PG   42.413793  ...  2.125  3.3  116.0  10.349138  7.785276  0.0  4.525  7.95
# SF   43.015038  ...  2.100  3.4  133.0   8.336090  6.227460  0.0  3.900  6.70
# SG   41.714286  ...  1.900  3.3  161.0   8.757143  6.247607  0.0  4.500  7.30
#
#
#        75%   max
# Pos
# C    10.25  33.1
# PF   11.20  31.1
# PG   14.45  32.4
# SF   11.10  30.1
# SG   11.10  28.3
#
# [5 rows x 208 columns]

# %% [markdown]
# **Histograms**

# %%
# Create a subset dataframe
pts = df[["Pos", "PTS"]]

positions = ['C','PF','SF','PG','SG']
pts = pts[ pts['Pos'].isin(positions)]

pts
# Out:
#     Pos   PTS
# 0     C   9.2
# 1     C   8.6
# 2     C  20.4
# 3    SG   7.9
# 4    PF   9.0
# ..   ..   ...
# 674  PF   4.4
# 675  PG  26.2
# 676   C   4.4
# 677   C   6.5
# 678   C  10.8
#
# [670 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

h = sns.FacetGrid(pts, col = )
